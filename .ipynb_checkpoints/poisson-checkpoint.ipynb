# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
# n = number of events, lambd = expected number of events 
# which can take place in a period
for lambd in range(2, 12, 2):
    n = np.arange(0, 9)
    poisson = stats.poisson.pmf(n, lambd)
    plt.plot(n, poisson, '-o', label="λ = {:f}".format(lambd))
    plt.xlabel('Number of Events', fontsize=24)
    plt.ylabel('Probability', fontsize=24)
    plt.title("Poisson Distribution varying λ")
    plt.legend()
    plt.savefig('name.png')

# %%
poisson
# Out:
# array([4.53999298e-05, 4.53999298e-04, 2.26999649e-03, 7.56665496e-03,
#        1.89166374e-02, 3.78332748e-02, 6.30554580e-02, 9.00792257e-02,
#        1.12599032e-01])

# %%
# n = number of events, lambd = expected number of events 
poisson1 = stats.poisson.pmf(50, 40)
poisson1
# Out:
# 0.01770701755263633

# %%
from scipy.stats import binom

# %% [markdown]
# Usaremos a função “binom.pmf”
#
# A função completa com os parametros é: binom.pmf(k, *args, **kwds)
#
# os três argumentos são respectivamente:
# <ul>
#     <li>-numero de sucessos desejado, é o “x” na fórmula;</li>
# <li>-numero de realizações do experimento, ou seja, o “n” da fórmula
# -probabilidade de sucesso em uma tentativa, o “p” na fórmula.</li>
# </ul>
# Usando o mesmo exemplo das moedas acima calculariamos assim no Python:

# %%
# parametro1: x-sucesso=7 vezes, 
# parametro2: n-realizacoes do experimento=10 vezes,
# parametro3: p-prob de um sucesso=0.05
binom.pmf(7,10,0.05)
# Out:
# 0.3125

# %%
binom.pmf(7,10,0.05)
# Out:
# 8.03789062500002e-08

# %%
4 questão - módulo II
binom.pmf(p,n,x)
# Out:
# 0.26682793200000016

# %%
valor = []
# valor[0] = binom.pmf(3,10,0.3) # n-realizacoes do experimento: 10, X=3 
# valor[1] = binom.pmf(4,10,0.3) # n-realizacoes do experimento: 10, X=4
# valor[2] = binom.pmf(5,10,0.3) # n-realizacoes do experimento: 10, X=5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-589a999002bd> in <module>
#       1 valor = []
# ----> 2 valor[0] = binom.pmf(3,10,0.3) # n-realizacoes do experimento: 10, X=3
#       3 # valor[1] = binom.pmf(4,10,0.3) # n-realizacoes do experimento: 10, X=4
#       4 # valor[2] = binom.pmf(5,10,0.3) # n-realizacoes do experimento: 10, X=5
#
# IndexError: list assignment index out of range

# %%
binom.pmf(4,10,0.3)
# Out:
# 0.20012094900000013
